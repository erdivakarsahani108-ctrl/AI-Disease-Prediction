# %% [markdown]
# # Exploratory Data Analysis (EDA)
#
# AI-Based Disease Prediction & Intelligent Health Assistant
#
# This notebook explores the processed `data/processed/disease_dataset.csv` dataset: shape, class distribution, symptom frequency, disease-symptom relationships and class imbalance, using the same chart functions used by the Streamlit Data Science Dashboard (`src/visualization/eda_charts.py`).

# %%
import sys, pathlib
ROOT = pathlib.Path.cwd().parent if (pathlib.Path.cwd() / '..' / 'src').exists() else pathlib.Path.cwd()
sys.path.insert(0, str(ROOT))
sys.path.insert(0, str(ROOT / 'scripts'))
import pandas as pd
pd.set_option('display.max_columns', 20)

# %%
from src.ml.data_loader import load_dataset, get_feature_columns
from src.visualization import eda_charts

df = load_dataset()
feature_cols = get_feature_columns(df)
print('Shape:', df.shape)
print('Diseases:', df['disease'].nunique())
print('Symptom features:', len(feature_cols))
print('Missing values:', df.isna().sum().sum())
print('Duplicate rows:', df.duplicated().sum())
# Out:
# Shape: (10301, 138)
# Diseases: 41
# Symptom features: 131
# Missing values: 0
# Duplicate rows: 0

# %% [markdown]
# ## Disease Distribution

# %%
eda_charts.disease_distribution_chart(df)

# %% [markdown]
# ## Disease Category Distribution

# %%
eda_charts.category_distribution_chart(df)

# %% [markdown]
# ## Most Frequent Symptoms

# %%
eda_charts.symptom_frequency_chart(df)

# %% [markdown]
# ## Disease vs Symptom Heatmap

# %%
eda_charts.disease_symptom_heatmap(df)

# %% [markdown]
# ## Class Imbalance

# %%
eda_charts.class_imbalance_chart(df)
df['disease'].value_counts().describe()
# Out:
# count     41.000000
# mean     251.243902
# std      264.051584
# min       11.000000
# 25%       26.000000
# 50%       57.000000
# 75%      600.000000
# max      600.000000
# Name: count, dtype: float64

# %% [markdown]
# ## Real vs Synthetic Records

# %%
eda_charts.real_vs_synthetic_chart(df)

# %% [markdown]
# ## Symptoms-per-Record Distribution

# %%
eda_charts.symptom_count_distribution(df)

# %% [markdown]
# ## Summary
#
# - The dataset combines a small set of REAL disease-symptom combinations from a public source with documented SYNTHETIC augmentation (see `docs/dataset_methodology.md`).
# - Class imbalance is real and expected (see `docs/data_quality_report.md`) because different diseases have very different numbers of validated real symptom combinations - this is handled downstream via `class_weight='balanced'` and macro-averaged evaluation metrics.
